# %% [markdown]
# A variable is like a container that stores information. Imagine a labelled box where we keep different items. The label helps us identify what is inside the box.
#
# In programming, a variable allows us to store data so we can reuse it later.

# %%
name = 'Dayo'
age = 30

firstName = 'Smith'
lastName = 'Oyeniyi'

print(f' My name is {firstName} {lastName} and I am {age} years old.')
# Out:
#  My name is Smith Oyeniyi and I am 30 years old.

# %%
print(name)
# Out:
# Dayo

# %% [markdown]
# Data Types in Python

# %%
age

print(name1)
# Out:
# Day
